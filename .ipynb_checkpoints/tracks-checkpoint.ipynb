# %% [markdown]
# chargement de donnée:

# %%
import numpy as np
data_array = np.load('ChampionshipCup2019_track.npy')
print("\nData summary:\n", data_array)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5edfeb992b6c> in <module>
# ----> 1 import numpy as np
#       2 data_array = np.load('ChampionshipCup2019_track.npy')
#       3 print("\nData summary:\n", data_array)
#
# ModuleNotFoundError: No module named 'numpy'
